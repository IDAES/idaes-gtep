# %%
import networkx as nx
import pandas as pd

# %%
buses_df = pd.read_csv("bus.csv")

# %%
gens_df = pd.read_csv("gen.csv")
branch_df = pd.read_csv("branch.csv")

# %%
adjacency_df = branch_df[["From Bus","To Bus"]]
edges = list(zip(adjacency_df["From Bus"], adjacency_df["To Bus"]))

# %%
network_graph = nx.from_edgelist(edges)

# %%
nx.is_connected(network_graph)
# Out:
# True
